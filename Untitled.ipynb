# %%
import torch.nn as nn
from network import GCNet
from train import prepare_data, train_model, plot_results

# %%
data_folder = "mesh_files/b05_refined_near_boundary/"
model = GCNet(3, [64, 64], 1)
lr_0 = 0.001
loss_func = nn.L1Loss()
with_eikonal_loss = False
n_epoch = 5

# %%
train_data = prepare_data(data_folder)
# Out:
# reading data

# %%
train_model(model, train_data, lr_0=lr_0, loss_func=loss_func)

# %%
plot_results(model, train_data, plot_every=5)

# %%
for d in
